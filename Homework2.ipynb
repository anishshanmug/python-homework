# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = pd.read_csv('Seasons_stats.csv',index_col=0)
data=data.fillna("0")
data
# Out:
#        Year             Player  Pos Age   Tm   G  GS    MP   PER    TS%  ...  \
# 0      1950    Curly Armstrong  G-F  31  FTW  63   0     0     0  0.368  ...
# 1      1950       Cliff Barker   SG  29  INO  49   0     0     0  0.435  ...
# 2      1950      Leo Barnhorst   SF  25  CHS  67   0     0     0  0.394  ...
# 3      1950         Ed Bartels    F  24  TOT  15   0     0     0  0.312  ...
# 4      1950         Ed Bartels    F  24  DNN  13   0     0     0  0.308  ...
# ...     ...                ...  ...  ..  ...  ..  ..   ...   ...    ...  ...
# 24686  2017        Cody Zeller   PF  24  CHO  62  58  1725  16.7  0.604  ...
# 24687  2017       Tyler Zeller    C  27  BOS  51   5   525    13  0.508  ...
# 24688  2017  Stephen Zimmerman    C  20  ORL  19   0   108   7.3  0.346  ...
# 24689  2017        Paul Zipser   SF  22  CHI  44  18   843   6.9  0.503  ...
# 24690  2017        Ivica Zubac    C  19  LAL  38  11   609    17  0.547  ...
#
#          FT%  ORB  DRB  TRB  AST STL BLK TOV   PF  PTS
# 0      0.705    0    0    0  176   0   0   0  217  458
# 1      0.708    0    0    0  109   0   0   0   99  279
# 2      0.698    0    0    0  140   0   0   0  192  438
# 3      0.559    0    0    0   20   0   0   0   29   63
# 4      0.548    0    0    0   20   0   0   0   27   59
# ...      ...  ...  ...  ...  ...  ..  ..  ..  ...  ...
# 24686  0.679  135  270  405   99  62  58  65  189  639
# 24687  0.564   43   81  124   42   7  21  20   61  178
# 24688    0.6   11   24   35    4   2   5   3   17   23
# 24689  0.775   15  110  125   36  15  16  40   78  240
# 24690  0.653   41  118  159   30  14  33  30   66  284
#
# [24691 rows x 52 columns]

# %%
data2 = np.arange(1,24692)
for i in range(0,24691):
    x=str(i)
    data2[i]=x
data2=data2.astype(str)
for i in range(0,24690):
    x=str("player"+ data2[i+1])
    data2[i]=x
data2[24690]="player24691"
data.index=data2.tolist()

# %%
data
# Out:
#              Year             Player  Pos Age   Tm   G  GS    MP   PER    TS%  \
# player1      1950    Curly Armstrong  G-F  31  FTW  63   0     0     0  0.368
# player2      1950       Cliff Barker   SG  29  INO  49   0     0     0  0.435
# player3      1950      Leo Barnhorst   SF  25  CHS  67   0     0     0  0.394
# player4      1950         Ed Bartels    F  24  TOT  15   0     0     0  0.312
# player5      1950         Ed Bartels    F  24  DNN  13   0     0     0  0.308
# ...           ...                ...  ...  ..  ...  ..  ..   ...   ...    ...
# player24687  2017        Cody Zeller   PF  24  CHO  62  58  1725  16.7  0.604
# player24688  2017       Tyler Zeller    C  27  BOS  51   5   525    13  0.508
# player24689  2017  Stephen Zimmerman    C  20  ORL  19   0   108   7.3  0.346
# player24690  2017        Paul Zipser   SF  22  CHI  44  18   843   6.9  0.503
# player24691  2017        Ivica Zubac    C  19  LAL  38  11   609    17  0.547
#
#              ...    FT%  ORB  DRB  TRB  AST STL BLK TOV   PF  PTS
# player1      ...  0.705    0    0    0  176   0   0   0  217  458
# player2      ...  0.708    0    0    0  109   0   0   0   99  279
# player3      ...  0.698    0    0    0  140   0   0   0  192  438
# player4      ...  0.559    0    0    0   20   0   0   0   29   63
# player5      ...  0.548    0    0    0   20   0   0   0   27   59
# ...          ...    ...  ...  ...  ...  ...  ..  ..  ..  ...  ...
# player24687  ...  0.679  135  270  405   99  62  58  65  189  639
# player24688  ...  0.564   43   81  124   42   7  21  20   61  178
# player24689  ...    0.6   11   24   35    4   2   5   3   17   23
# player24690  ...  0.775   15  110  125   36  15  16  40   78  240
# player24691  ...  0.653   41  118  159   30  14  33  30   66  284
#
# [24691 rows x 52 columns]

# %%
data.groupby(['Age','PTS']).size().unstack().plot(kind='bar',stacked=True)
plt.show()
